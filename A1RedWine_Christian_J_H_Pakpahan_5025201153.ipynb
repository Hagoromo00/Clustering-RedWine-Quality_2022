# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt
import sklearn
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
import time 
from datetime import date
from sklearn import metrics
from sklearn.metrics import pairwise_distances



wine = pd.read_csv('winequality-red.csv')
wine.shape

X = wine.iloc[:,0:11]
y = wine['quality']

X_scaled = StandardScaler().fit_transform(X)


#Applying kmeans to data, k=2
kmeans = KMeans(n_clusters = 2)
start_time = time.time()                                                                                               
clusters = kmeans.fit_predict(X_scaled)
today = date.today()
print("--- %s seconds ---" % (time.time() - start_time))
labels = kmeans.labels_


#2D plot
colors = 'rgbkcmy'
for i in np.unique(clusters):
    plt.scatter(X_scaled[clusters==i,0],
               X_scaled[clusters==i,1],
               color=colors[i], label='Cluster' + str(i+1))
#plt.legend()  

#try to find optimal k using the elbow method
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300, n_init=12, random_state=0)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)
f3, ax = plt.subplots(figsize=(8, 6))
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

#Visualize clusters considering fixed acidity, residual sugar and alcohol
fig = plt.figure(figsize=(20, 15))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=15, azim=40)

ax.scatter(X_scaled[:,0], X_scaled[:,3], X_scaled[:,10],c=y, edgecolor='k')
ax.set_xlabel('Acidity')
ax.set_ylabel('Sugar')
ax.set_zlabel('Alcohol')
ax.set_title('K=2: Acidity, Sugar, Alcohol', size=22)
#Text(0.5, 0.92, 'K=2: Acidity, Sugar, Alcohol')
# Out:
# --- 0.17616677284240723 seconds ---
# Text(0.5, 0.92, 'K=2: Acidity, Sugar, Alcohol')

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.0-py3-none-any.whl (285 kB)
#      ------------------------------------ 285.1/285.1 kB 366.5 kB/s eta 0:00:00
# Collecting matplotlib>=3.1
#   Using cached matplotlib-3.6.0-cp310-cp310-win_amd64.whl (7.2 MB)
# Requirement already satisfied: numpy>=1.17 in c:\python310\lib\site-packages (from seaborn) (1.23.3)
# Requirement already satisfied: pandas>=0.25 in c:\python310\lib\site-packages (from seaborn) (1.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from matplotlib>=3.1->seaborn) (3.0.9)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib>=3.1->seaborn) (4.37.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from matplotlib>=3.1->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\python310\lib\site-packages (from matplotlib>=3.1->seaborn) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python310\site-packages (from matplotlib>=3.1->seaborn) (2.8.2)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.5-cp310-cp310-win_amd64.whl (164 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas>=0.25->seaborn) (2022.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib>=3.1->seaborn) (1.16.0)
# Installing collected packages: cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.0.5 cycler-0.11.0 matplotlib-3.6.0 seaborn-0.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.2-cp310-cp310-win_amd64.whl (7.4 MB)
#      ---------------------------------------- 7.4/7.4 MB 1.1 MB/s eta 0:00:00
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.1-cp310-cp310-win_amd64.whl (38.6 MB)
#      -------------------------------------- 38.6/38.6 MB 443.5 kB/s eta 0:00:00
# Collecting joblib>=1.0.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ------------------------------------ 298.0/298.0 kB 307.1 kB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\python310\lib\site-packages (from scikit-learn->sklearn) (1.23.3)
# Using legacy 'setup.py install' for sklearn, since package 'wheel' is not installed.
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sklearn
#   Running setup.py install for sklearn: started
#   Running setup.py install for sklearn: finished with status 'done'
# Successfully installed joblib-1.2.0 scikit-learn-1.1.2 scipy-1.9.1 sklearn-0.0 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.6.0-cp310-cp310-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 177.6 kB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.37.3-py3-none-any.whl (959 kB)
#      ------------------------------------ 960.0/960.0 kB 799.4 kB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.3/55.3 kB ? eta 0:00:00
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp310-cp310-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.5-cp310-cp310-win_amd64.whl (164 kB)
#      ------------------------------------ 164.1/164.1 kB 900.0 kB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: numpy>=1.19 in c:\python310\lib\site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Python310\\share'
# Consider using the `--user` option or check the permissions.
